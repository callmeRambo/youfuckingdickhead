# %%
#import codecs

def read_data(file_path):
	with open(file_path,encoding="ISO-8859-1") as f:
		lines = f.read().splitlines()
	return lines

#unknown|0
#Action|1
#Adventure|2
#Animation|3
#Children's|4
#Comedy|5
#Crime|6
#Documentary|7
#Drama|8
#Fantasy|9
#Film-Noir|10
#Horror|11
#Musical|12
#Mystery|13
#Romance|14
#Sci-Fi|15
#Thriller|16
#War|17
#Western|18

def movie_genre(file_path):
    lines = read_data(file_path)
    genre = {}
    for line in lines:
        if line =='':
            break
        data=str(line).split("|")
        genre[data[0]]=data[1]
    return genre

def user_occupation():
    occupations = "administrator,artist,doctor,educator,engineer,entertainment,executive,healthcare,homemaker,lawyer,librarian,marketing\
    ,none,other,programmer,retired,salesman,scientist,student,technician,writer".replace(" ","").split(",")
    return occupations


#	 user id | item id | rating | timestamp. 

def rating_data_dic(file_path):
    lines = read_data(file_path)
    u_data = []
    for line in lines:
        data_slice=str(line).split("\t")
        #for i in line:
        data_slice_dic = {}
        data_slice_dic["user id"]=data_slice[0]
        data_slice_dic["item id"]=data_slice[1]
        data_slice_dic["rating"]=data_slice[2]
        data_slice_dic["timestamp"]=data_slice[3]
        u_data.append(data_slice_dic)
    return u_data

#movie id | movie title | release date | video release date |
#              IMDb URL | unknown | Action | Adventure | Animation |
#              Children's | Comedy | Crime | Documentary | Drama | Fantasy |
#              Film-Noir | Horror | Musical | Mystery | Romance | Sci-Fi |
#              Thriller | War | Western |
def movie_data_dic(file_path):
    lines = read_data(file_path)
    u_data = []
    for line in lines:
        data_slice=str(line).split("|")
        #for i in line:
        data_slice_dic = {}
        data_slice_dic["movie id"]=data_slice[0]
        data_slice_dic["movie title"]=data_slice[1]
        data_slice_dic["release date"]=data_slice[2]
        data_slice_dic["video release date"]=data_slice[3]
        data_slice_dic["IMDb URL"]=data_slice[4]
        data_slice_dic["unknown"]=data_slice[5]
        data_slice_dic["Action"]=data_slice[6]
        data_slice_dic["Adventure"]=data_slice[7]
        data_slice_dic["Animation"]=data_slice[8]
        data_slice_dic["Children's"]=data_slice[9]
        data_slice_dic["Comedy"]=data_slice[10]
        data_slice_dic["Crime"]=data_slice[11]
        data_slice_dic["Documentary"]=data_slice[12]
        data_slice_dic["Drama"]=data_slice[13]
        data_slice_dic["Fantasy"]=data_slice[14]
        data_slice_dic["Film-Noir"]=data_slice[15]
        data_slice_dic["Horror"]=data_slice[16]
        data_slice_dic["Musical"]=data_slice[17]
        data_slice_dic["Mystery"]=data_slice[18]
        data_slice_dic["Romance"]=data_slice[19]
        data_slice_dic["Sci-Fi"]=data_slice[20]
        data_slice_dic["Thriller"]=data_slice[21]
        data_slice_dic["War"]=data_slice[22]
        data_slice_dic["Western"]=data_slice[23]
        u_data.append(data_slice_dic)
    return u_data
#  user id | age | gender | occupation | zip code
def user_data_dic(file_path):
    lines = read_data(file_path)
    u_data = []
    for line in lines:
        data_slice=str(line).split("|")
        #for i in line:
        data_slice_dic = {}
        data_slice_dic["user id"]=data_slice[0]
        data_slice_dic["age"]=data_slice[1]
        data_slice_dic["gender"]=data_slice[2]
        data_slice_dic["occupation"]=data_slice[3]
        data_slice_dic["zip code"]=data_slice[4]
        u_data.append(data_slice_dic)
    return u_data

# %%
movie_genre("u.genre")
user_occupation()
# Out:
# ['administrator',
#  'artist',
#  'doctor',
#  'educator',
#  'engineer',
#  'entertainment',
#  'executive',
#  'healthcare',
#  'homemaker',
#  'lawyer',
#  'librarian',
#  'marketing',
#  'none',
#  'other',
#  'programmer',
#  'retired',
#  'salesman',
#  'scientist',
#  'student',
#  'technician',
#  'writer']
